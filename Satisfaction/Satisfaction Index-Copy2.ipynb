# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import sys
from time import strftime
#import tensorflow as tf
#import keras
import requests
import json
import pickle
from flask import Flask, request, jsonify
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder, StandardScaler,MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import mutual_info_regression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import  KNeighborsClassifier
from sklearn.neural_network import  MLPClassifier
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('employees (1) (1) (1) (2).csv')
data
# Out:
#        avg_monthly_hrs   department  last_evaluation  n_projects  salary  \
# 0                  221  engineering         0.932868           4     low
# 1                  232      support              NaN           3     low
# 2                  184        sales         0.788830           3  medium
# 3                  206        sales         0.575688           4     low
# 4                  249        sales         0.845217           3     low
# ...                ...          ...              ...         ...     ...
# 13994              266      support         0.803680           4  medium
# 13995              162  engineering         0.714147           5  medium
# 13996              260      finance         0.450067           4     low
# 13997              142           IT         0.615612           3     low
# 13998              240  engineering         0.886119           5     low
#
#        satisfaction    status  tenure                               Agency  \
# 0          0.829896      Left     5.0                 South Gate, New York
# 1          0.834544  Employed     2.0                  Miami Gardens, Iowa
# 2          0.834988  Employed     3.0                    Danville, Florida
# 3          0.424764  Employed     2.0              Hallandale Beach, Texas
# 4          0.779043  Employed     3.0  North Richland Hills, Massachusetts
# ...             ...       ...     ...                                  ...
# 13994      0.920262  Employed     3.0                  Fremont, California
# 13995      0.544542  Employed     3.0                West Des Moines, Ohio
# 13996      0.933908  Employed     4.0               Euclid, South Carolina
# 13997      0.528197  Employed     4.0                  Rockville, Arkansas
# 13998      0.766197      Left     6.0                 Montclair, Tennessee
#
#             EmployeeName  age  rating  salary.1        fname    lname
# 0         NATHANIEL FORD   43     1.4    567595    NATHANIEL     FORD
# 1             Rohan Rane   47     2.2    538909        Rohan     Rane
# 2         ALBERT PARDINI   38     4.7    335279       ALBERT  PARDINI
# 3      CHRISTOPHER CHONG   39     4.8    332343  CHRISTOPHER    CHONG
# 4        PATRICK GARDNER   33     4.3    326373      PATRICK  GARDNER
# ...                  ...  ...     ...       ...          ...      ...
# 13994       DENISE PIERI   48     3.5     81432       DENISE    PIERI
# 13995     LOURDES TORRES   37     4.3     81432      LOURDES   TORRES
# 13996   ANGELICA SALAZAR   23     4.2     81432     ANGELICA  SALAZAR
# 13997        NANCY SESSA   34     4.3     81432        NANCY    SESSA
# 13998         LINDA CHAN   34     4.1     81432        LINDA     CHAN
#
# [13999 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# avg_monthly_hrs       0
# department          695
# last_evaluation    1508
# n_projects            0
# salary                0
# satisfaction        177
# status                0
# tenure              177
# Agency                0
# EmployeeName          0
# age                   0
# rating                0
# salary.1              0
# fname                 0
# lname                 0
# dtype: int64

# %%
data['last_evaluation'].fillna('0',inplace=True)

# %%
data.isnull().sum()
# Out:
# avg_monthly_hrs      0
# department         695
# last_evaluation      0
# n_projects           0
# salary               0
# satisfaction       177
# status               0
# tenure             177
# Agency               0
# EmployeeName         0
# age                  0
# rating               0
# salary.1             0
# fname                0
# lname                0
# dtype: int64

# %%
data['department'].fillna('support',inplace=True)

# %%
data['satisfaction'].fillna('0.0',inplace=True)

# %%
data['tenure'].fillna('0',inplace=True)

# %%
data.isnull().sum()
# Out:
# avg_monthly_hrs    0
# department         0
# last_evaluation    0
# n_projects         0
# salary             0
# satisfaction       0
# status             0
# tenure             0
# Agency             0
# EmployeeName       0
# age                0
# rating             0
# salary.1           0
# fname              0
# lname              0
# dtype: int64

# %%
le = LabelEncoder()

# %%
label = le.fit_transform(data['EmployeeName'])
label
# Out:
# array([ 9627, 11545,   174, ...,   569,  9579,  7779])

# %%
label = le.fit_transform(data['Agency'])
label
# Out:
# array([8109, 5345, 2160, ..., 2764, 7351, 5564])

# %%
label = le.fit_transform(data['fname'])
label
# Out:
# array([2265, 2703,   48, ...,  156, 2249, 1846])

# %%
label = le.fit_transform(data['lname'])
label
# Out:
# array([2346, 5870, 5143, ..., 5905, 6104, 1213])

# %%
data.drop("EmployeeName", axis=1, inplace=True)

# %%
data.drop("Agency", axis=1, inplace=True)

# %%
data.drop("fname", axis=1, inplace=True)

# %%
data.drop("lname", axis=1, inplace=True)

# %%
data["EmployeeName"] = label

# %%
data["Agency"] = label

# %%
data["fname"] = label

# %%
data["lname"] = label

# %%
data.head()
# Out:
#    avg_monthly_hrs   department last_evaluation  n_projects  salary  \
# 0              221  engineering        0.932868           4     low
# 1              232      support               0           3     low
# 2              184        sales         0.78883           3  medium
# 3              206        sales        0.575688           4     low
# 4              249        sales        0.845217           3     low
#
#   satisfaction    status tenure  age  rating  salary.1  EmployeeName  Agency  \
# 0     0.829896      Left    5.0   43     1.4    567595          2346    2346
# 1     0.834544  Employed    2.0   47     2.2    538909          5870    5870
# 2     0.834988  Employed    3.0   38     4.7    335279          5143    5143
# 3     0.424764  Employed    2.0   39     4.8    332343          1281    1281
# 4     0.779043  Employed    3.0   33     4.3    326373          2505    2505
#
#    fname  lname
# 0   2346   2346
# 1   5870   5870
# 2   5143   5143
# 3   1281   1281
# 4   2505   2505

# %%
data['status']=data['status'].map({'Employed':1,'Left':0})
data.head()
# Out:
#    avg_monthly_hrs   department last_evaluation  n_projects  salary  \
# 0              221  engineering        0.932868           4     low
# 1              232      support               0           3     low
# 2              184        sales         0.78883           3  medium
# 3              206        sales        0.575688           4     low
# 4              249        sales        0.845217           3     low
#
#   satisfaction  status tenure  age  rating  salary.1  EmployeeName  Agency  \
# 0     0.829896       0    5.0   43     1.4    567595          2346    2346
# 1     0.834544       1    2.0   47     2.2    538909          5870    5870
# 2     0.834988       1    3.0   38     4.7    335279          5143    5143
# 3     0.424764       1    2.0   39     4.8    332343          1281    1281
# 4     0.779043       1    3.0   33     4.3    326373          2505    2505
#
#    fname  lname
# 0   2346   2346
# 1   5870   5870
# 2   5143   5143
# 3   1281   1281
# 4   2505   2505

# %%
data['salary']=data['salary'].map({'low':0,'medium':1,'high':2})
data.head()
# Out:
#    avg_monthly_hrs   department last_evaluation  n_projects  salary  \
# 0              221  engineering        0.932868           4       0
# 1              232      support               0           3       0
# 2              184        sales         0.78883           3       1
# 3              206        sales        0.575688           4       0
# 4              249        sales        0.845217           3       0
#
#   satisfaction  status tenure  age  rating  salary.1  EmployeeName  Agency  \
# 0     0.829896       0    5.0   43     1.4    567595          2346    2346
# 1     0.834544       1    2.0   47     2.2    538909          5870    5870
# 2     0.834988       1    3.0   38     4.7    335279          5143    5143
# 3     0.424764       1    2.0   39     4.8    332343          1281    1281
# 4     0.779043       1    3.0   33     4.3    326373          2505    2505
#
#    fname  lname
# 0   2346   2346
# 1   5870   5870
# 2   5143   5143
# 3   1281   1281
# 4   2505   2505

# %%
data['department']=data['department'].map({'product':0,'sales':1,'support':2,'temp':3,'IT':4,'admin':5,'engineering':6,'finance':7,'information_technology':8,'management':9,'marketing':10,'procurement':11})

# %%
data.groupby('department')['satisfaction'].count().plot(kind='pie',autopct='%1.1f%%',shadow=True,figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %%
data.groupby('n_projects')['satisfaction'].count().plot(kind='pie',autopct='%1.1f%%',shadow=True,figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %%
data.groupby('salary')['satisfaction'].count().plot(kind='pie',autopct='%1.1f%%',shadow=True,figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %%
data.groupby('tenure')['satisfaction'].count().plot(kind='pie',autopct='%1.1f%%',shadow=True,figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %%
data.groupby('status')['satisfaction'].count().plot(kind='pie',autopct='%1.1f%%',shadow=True,figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %% [markdown]
# Proper conclusions that can be drawn from the visualizations are that 76.1% people who are still employed are also satisfied whereas the remaining are not.
# Employees who are in their prime years i.e having a tenure of around 2-5 years tend to be more satisfied. As their tenure starts growing, they start become more and more unsatisfied.

# %%
data.corr().head()
# Out:
#                  avg_monthly_hrs  department  n_projects    salary    status  \
# avg_monthly_hrs         1.000000    0.011608    0.443610 -0.003195 -0.071353
# department              0.011608    1.000000    0.017205  0.076104  0.025027
# n_projects              0.443610    0.017205    1.000000 -0.002306 -0.025639
# salary                 -0.003195    0.076104   -0.002306  1.000000  0.155476
# status                 -0.071353    0.025027   -0.025639  0.155476  1.000000
#
#                       age    rating  salary.1  EmployeeName    Agency  \
# avg_monthly_hrs -0.007499  0.011793  0.003059     -0.000813 -0.000813
# department       0.001865 -0.007111 -0.014313     -0.004502 -0.004502
# n_projects      -0.002988  0.001304 -0.006375     -0.006651 -0.006651
# salary          -0.004528  0.018247  0.000365      0.008272  0.008272
# status          -0.011951  0.012489 -0.004311      0.003536  0.003536
#
#                     fname     lname
# avg_monthly_hrs -0.000813 -0.000813
# department      -0.004502 -0.004502
# n_projects      -0.006651 -0.006651
# salary           0.008272  0.008272
# status           0.003536  0.003536

# %%
plt.figure(figsize=(16,10))
sns.heatmap(data.corr(), annot=True, annot_kws={"size": 14})
sns.set_style('white')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.kdeplot(data['salary'],shade=True)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.kdeplot(data['avg_monthly_hrs'],shade=True)
plt.show()

# %%
sns.pairplot(data)

# %%
data = data.drop(['Agency'],axis=1)

# %%
data = data.drop(['EmployeeName'],axis=1)

# %%
data = data.drop(['fname'],axis=1)

# %%
data=data.drop(['lname'],axis=1)

# %%
data = data.drop(['avg_monthly_hrs'],axis=1)

# %%
data = data.drop(['last_evaluation'],axis=1)

# %%
data.head()
# Out:
#    department  n_projects  salary satisfaction  status tenure  age  rating  \
# 0           6           4       0     0.829896       0    5.0   43     1.4
# 1           2           3       0     0.834544       1    2.0   47     2.2
# 2           1           3       1     0.834988       1    3.0   38     4.7
# 3           1           4       0     0.424764       1    2.0   39     4.8
# 4           1           3       0     0.779043       1    3.0   33     4.3
#
#    salary.1
# 0    567595
# 1    538909
# 2    335279
# 3    332343
# 4    326373

# %%
target = np.array(data.drop(['satisfaction'],1))
features = np.array(data['satisfaction'])

# %%
target[0]
# Out:
# array([6, 4, 0, 0, 5.0, 43, 1.4, 567595], dtype=object)

# %%
x_train , x_test , y_train , y_test = train_test_split(target,features,test_size=0.25,random_state=42)

len(x_train)/len(features)
# Out:
# 0.7499821415815415

# %%
print(f'Shape of x_train is {x_train.shape}')
print(f'Shape of x_test is {x_test.shape}')
print(f'Shape of y_train is {y_train.shape}')
print(f'Shape of y_test is {y_test.shape}')
# Out:
# Shape of x_train is (10499, 8)
# Shape of x_test is (3500, 8)
# Shape of y_train is (10499,)
# Shape of y_test is (3500,)

# %%
rf_model = RandomForestRegressor(random_state = 42).fit(x_train, y_train)

# %%
y_pred = rf_model.predict(x_test)
rf_base = np.sqrt(mean_squared_error(y_test, y_pred))
rf_base
# Out:
# 0.18998153914443505

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(x_test)
dt_base = np.sqrt(mean_squared_error(y_test, y_pred))
dt_base
# Out:
# 0.2616063939635787

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

results = pd.DataFrame([['Multiple Linear Regression', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(x_train)
lr_poly_regressor = LinearRegression()
lr_poly_regressor.fit(X_poly, y_train)

# Predicting Test Set
y_pred = lr_poly_regressor.predict(poly_reg.fit_transform(x_test))

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

model_results = pd.DataFrame([['Polynomial Regression', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

results = results.append(model_results, ignore_index = True)

# %%
from sklearn.tree import DecisionTreeRegressor
dt_regressor = DecisionTreeRegressor(random_state=0)
dt_regressor.fit(x_train, y_train)

# Predicting Test Set
y_pred = dt_regressor.predict(x_test)
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

model_results = pd.DataFrame([['Decision Tree Regression', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

results = results.append(model_results, ignore_index = True)

# %%
## Random Forest Regression
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=300, random_state=0)
rf_regressor.fit(x_train,y_train)

# Predicting Test Set
y_pred = rf_regressor.predict(x_test)
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

model_results = pd.DataFrame([['Random Forest Regression', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

results = results.append(model_results, ignore_index = True)

# %%
##Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor
gb_regressor = GradientBoostingRegressor()
gb_regressor.fit(x_train, y_train)

# Predicting Test Set
y_pred = gb_regressor.predict(x_test)
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

model_results = pd.DataFrame([['GradientBoosting Regressor', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

results = results.append(model_results, ignore_index = True)

# %%
## Ada Boosting
from sklearn.ensemble import AdaBoostRegressor
ad_regressor = AdaBoostRegressor()
ad_regressor.fit(x_train, y_train)

# Predicting Test Set
y_pred = ad_regressor.predict(x_test)
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

model_results = pd.DataFrame([['AdaBoost Regressor', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

results = results.append(model_results, ignore_index = True)

# %%
#The Best Regressor 
print('The best regressor is:')
print('{}'.format(results.sort_values(by='R2 Score',ascending=False).head(5)))
# Out:
# The best regressor is:
#                         Model       MAE       MSE      RMSE  R2 Score
# 4  GradientBoosting Regressor  0.141069  0.034190  0.184906  0.475907
# 3    Random Forest Regression  0.142795  0.036015  0.189775  0.447940
# 5          AdaBoost Regressor  0.156588  0.038048  0.195059  0.416771
# 1       Polynomial Regression  0.158522  0.040441  0.201101  0.380083
# 0  Multiple Linear Regression  0.191273  0.068438  0.261606 -0.049068

# %%
import pickle
pickle.dump(gb_regressor,open('employee_satisfaction_1.pkl','wb'))

# %%
model = pickle.load(open('employee_satisfaction_1.pkl','rb'))

# %%
print(gb_regressor.predict([[6,4,0,1,5,43,1.4,567695]]))
# Out:
# [0.6477293]

# %%
print(gb_regressor.predict([[5,2,0,1,2,23,3.4,367695]]))
# Out:
# [0.66054027]

# %%
print(gb_regressor.predict([[1,1,0,0,2,33,4.4,347695]]))
# Out:
# [0.44745204]

# %%
print('Satisfaction index of the employee is:',gb_regressor.predict([[4,4,0,2,2,23,4.4,747695]]))
# Out:
# Satisfaction index of the employee is: [0.77184584]

# %%
print('Satisfaction index of the employee is:',gb_regressor.predict([[4,8,0,0,1,23,1.4,47695]]))
# Out:
# Satisfaction index of the employee is: [0.32307662]
